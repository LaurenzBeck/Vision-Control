# %%
import sys
assert sys.version_info >= (3, 5)

# %tensorflow_version 2.x
import tensorflow as tf 
from tensorflow import keras
assert tf.__version__ >= "2.0"

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

from time import time
import datetime

# %matplotlib inline
# %load_ext tensorboard

SEED = 42
SESSION_NAME = datetime.datetime.now().strftime("%Y%m%d_%H%M")
PI = tf.constant(np.pi)

print(SESSION_NAME)
# Out:
# 20191117_1315

# %% [markdown]
# Image Data

# %%
df_train=pd.read_csv("./labels_train.csv",dtype={'id': str, 'label': np.float32})
df_val=pd.read_csv("./labels_val.csv",dtype={'id': str, 'label': np.float32})
df_test=pd.read_csv("./labels_test.csv",dtype={'id': str, 'label': np.float32})
IMG_PATH_TRAIN = "images_train/"
IMG_PATH_VAL = "images_val/"
IMG_PATH_TEST = "images_test/"

df_train.head()

#Visualizing some Examples
fig = plt.figure(figsize=(10,5))
for i in range (1, 5):
    a = fig.add_subplot(2, 2, i)
    imgplot = plt.imshow(mpimg.imread(IMG_PATH_TRAIN+df_train.iloc[(i*10000)-1]['id']), cmap='gray', vmin=0, vmax=1)
    a.set_title(df_train.iloc[(i*10000)-1]['label']) 
    plt.tight_layout()

# %% [markdown]
# Data Augmentation Pipeline

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

HEIGHT = 480
WIDTH = 640
TARGET_HEIGHT = 480
TARGET_WIDTH = 640
CHANNELS = 1
BATCH_SIZE = 16
NUM_TRAIN_IMAGES = 80000
NUM_VAL_IMAGES = 10000
NUM_TEST_IMAGES = 10000

datagen = ImageDataGenerator(rescale = 1/256,
                             width_shift_range = 25,
                             height_shift_range = 25,
                             rotation_range = 5,
                             brightness_range = [0.7, 1.3],
                             zoom_range = 0.25)

train_generator = datagen.flow_from_dataframe(dataframe=df_train,
                                              directory=IMG_PATH_TRAIN,
                                              x_col="id",
                                              y_col="label",
                                              seed=SEED,
                                              batch_size=BATCH_SIZE,
                                              shuffle=True,
                                              class_mode="raw",
                                              target_size=(TARGET_HEIGHT,TARGET_WIDTH),
                                              color_mode = "grayscale")

val_generator = datagen.flow_from_dataframe(dataframe=df_val,
                                            directory=IMG_PATH_VAL,
                                            x_col="id",
                                            y_col="label",
                                            seed=SEED,
                                            batch_size=BATCH_SIZE,
                                            shuffle=False,
                                            class_mode="raw",
                                            target_size=(TARGET_HEIGHT,TARGET_WIDTH),
                                            color_mode = "grayscale")

test_datagen = ImageDataGenerator(rescale = 1/256)

test_generator = test_datagen.flow_from_dataframe(dataframe=df_test,
                                                  directory=IMG_PATH_TEST,
                                                  x_col="id",
                                                  y_col="label",
                                                  batch_size=BATCH_SIZE,
                                                  class_mode="raw",
                                                  shuffle=False,
                                                  target_size=(TARGET_HEIGHT,TARGET_WIDTH),
                                                  color_mode = "grayscale")

fig = plt.figure(figsize=(12,10))
for X_batch, y_batch in train_generator:
    for i in range(1, 9):
        image = ((X_batch[i-1]*256).astype('uint8'))[:,:,0]
        a = fig.add_subplot(4, 2, i)
        imgplot = plt.imshow(image, cmap='gray', vmin = 0, vmax = 256)
        a.set_title("{}".format(i))
        plt.tight_layout()
    break
# Out:
# Found 80000 validated image filenames.
# Found 10000 validated image filenames.
# Found 10000 validated image filenames.

# %% [markdown]
# Model Definition

# %%
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization, Conv2D, MaxPooling2D
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2

model = keras.models.Sequential([
    keras.layers.Conv2D(8, 7, activation="elu", padding="same", kernel_initializer="he_normal", input_shape=[TARGET_HEIGHT,TARGET_WIDTH,CHANNELS]),
    keras.layers.Conv2D(8, 3, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.BatchNormalization(),
    keras.layers.AveragePooling2D(pool_size=2),
    keras.layers.Conv2D(4, 1, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.Conv2D(8, 3, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.BatchNormalization(),
    keras.layers.AveragePooling2D(pool_size=2),
    keras.layers.Conv2D(4, 1, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.Conv2D(8, 3, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.BatchNormalization(),
    keras.layers.AveragePooling2D(pool_size=2),
    keras.layers.Conv2D(8, 1, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.Conv2D(16, 3, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.BatchNormalization(),
    keras.layers.AveragePooling2D(pool_size=2),
    keras.layers.Conv2D(8, 1, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.Conv2D(16, 3, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.BatchNormalization(),
    keras.layers.AveragePooling2D(pool_size=2),
    keras.layers.Conv2D(16, 1, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.Conv2D(32, 3, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.BatchNormalization(),
    keras.layers.AveragePooling2D(pool_size=2),
    keras.layers.Conv2D(16, 1, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.Conv2D(32, 3, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.BatchNormalization(),
    #keras.layers.AveragePooling2D(pool_size=2),
    keras.layers.GlobalAvgPool2D(),
    keras.layers.Flatten(),
    keras.layers.Dense(16, activation="elu"),
    keras.layers.Dropout(0.1),
    keras.layers.Dense(8, activation="elu"),
    keras.layers.Dense(1, activation="relu")
])

model.summary()

#tf.keras.utils.plot_model(
#    model,
#    to_file='model.png',
#    show_shapes=True,
#    show_layer_names=True,
#    rankdir='TB',
#    expand_nested=False,
#    dpi=96
#)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 480, 640, 8)       400
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 480, 640, 8)       584
# _________________________________________________________________
# batch_normalization (BatchNo (None, 480, 640, 8)       32
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 240, 320, 8)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 240, 320, 4)       36
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 240, 320, 8)       296
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 240, 320, 8)       32
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 120, 160, 8)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 120, 160, 4)       36
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 120, 160, 8)       296
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 120, 160, 8)       32
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 60, 80, 8)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 60, 80, 8)         72
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 60, 80, 16)        1168
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 60, 80, 16)        64
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 30, 40, 16)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 30, 40, 8)         136
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 30, 40, 16)        1168
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 30, 40, 16)        64
# _________________________________________________________________
# average_pooling2d_4 (Average (None, 15, 20, 16)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 15, 20, 16)        272
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 15, 20, 32)        4640
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 15, 20, 32)        128
# _________________________________________________________________
# average_pooling2d_5 (Average (None, 7, 10, 32)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 7, 10, 16)         528
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 7, 10, 32)         4640
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 7, 10, 32)         128
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 32)                0
# _________________________________________________________________
# flatten (Flatten)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 16)                528
# _________________________________________________________________
# dropout (Dropout)            (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 15,425
# Trainable params: 15,185
# Non-trainable params: 240
# _________________________________________________________________

# %% [markdown]
# Loss and Compilation

# %%
def squared_angdiff_and_mse(y_true, y_pred):
    squared_angdiff = tf.square( tf.atan2(tf.sin(y_pred - y_true), tf.cos(y_pred - y_true)) )
    mse = tf.square(y_pred - y_true)
    loss = tf.add(squared_angdiff, mse)
    return loss

def scheduler(epoch):
  if epoch < 3:
    return 0.004
  elif epoch < 6:
    return 0.002
  elif epoch < 20:
    return 0.001
  elif epoch < 30:
    return 0.0008
  else:
    return 0.0005

schedule = keras.callbacks.LearningRateScheduler(scheduler)

FILEPATH_SAVE='checkpoints\{}_model_weights.h5'.format(SESSION_NAME)
checkpoint = keras.callbacks.ModelCheckpoint(FILEPATH_SAVE,
                                             monitor=[squared_angdiff_and_mse],
                                             verbose=1,
                                             mode='min')

FILEPATH_TENSORBOARD_LOG = 'logs\{}'.format(SESSION_NAME)
tensorboard = keras.callbacks.TensorBoard(log_dir = FILEPATH_TENSORBOARD_LOG,
                                          histogram_freq=1,
                                          write_graph=True,
                                          write_images=True,
                                          update_freq=10000,
                                         )

model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.01,
                                                         beta_1=0.9,
                                                         beta_2=0.95,
                                                         epsilon=1e-07,
                                                         ),
              loss=squared_angdiff_and_mse,
              metrics=[squared_angdiff_and_mse, 'mae'])

# %% [markdown]
# Training

# %%
# Training constants
NUM_EPOCHS = 20

history = model.fit_generator(generator=train_generator, 
                              validation_data=val_generator,
                              validation_steps=625,
                              steps_per_epoch=5000,
                              epochs=NUM_EPOCHS,
                              callbacks=[tensorboard, checkpoint, schedule])
# Out:
# Epoch 1/20
# 4999/5000 [============================>.] - ETA: 0s - loss: 1.2089 - squared_angdiff_and_mse: 1.2089 - mae: 0.4683
# Epoch 00001: saving model to checkpoints\20191117_1315_model_weights.h5
# 5000/5000 [==============================] - 3513s 703ms/step - loss: 1.2087 - squared_angdiff_and_mse: 1.2087 - mae: 0.4682 - val_loss: 7.9333 - val_squared_angdiff_and_mse: 7.9333 - val_mae: 1.7875
# Epoch 2/20
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.3839 - squared_angdiff_and_mse: 0.3839 - mae: 0.2372
# Epoch 00002: saving model to checkpoints\20191117_1315_model_weights.h5
# 5000/5000 [==============================] - 3369s 674ms/step - loss: 0.3838 - squared_angdiff_and_mse: 0.3838 - mae: 0.2372 - val_loss: 0.4068 - val_squared_angdiff_and_mse: 0.4068 - val_mae: 0.2475
# Epoch 3/20
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.3289 - squared_angdiff_and_mse: 0.3289 - mae: 0.2100
# Epoch 00003: saving model to checkpoints\20191117_1315_model_weights.h5
# 5000/5000 [==============================] - 3264s 653ms/step - loss: 0.3289 - squared_angdiff_and_mse: 0.3289 - mae: 0.2100 - val_loss: 0.3585 - val_squared_angdiff_and_mse: 0.3585 - val_mae: 0.2312
# Epoch 4/20
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.2314 - squared_angdiff_and_mse: 0.2314 - mae: 0.1689
# Epoch 00004: saving model to checkpoints\20191117_1315_model_weights.h5
# 5000/5000 [==============================] - 3240s 648ms/step - loss: 0.2314 - squared_angdiff_and_mse: 0.2314 - mae: 0.1688 - val_loss: 0.1675 - val_squared_angdiff_and_mse: 0.1675 - val_mae: 0.1907
# Epoch 5/20
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.2107 - squared_angdiff_and_mse: 0.2107 - mae: 0.1583
# Epoch 00005: saving model to checkpoints\20191117_1315_model_weights.h5
# 5000/5000 [==============================] - 3358s 672ms/step - loss: 0.2107 - squared_angdiff_and_mse: 0.2107 - mae: 0.1583 - val_loss: 0.2224 - val_squared_angdiff_and_mse: 0.2224 - val_mae: 0.2063
# Epoch 6/20
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1976 - squared_angdiff_and_mse: 0.1976 - mae: 0.1548
# Epoch 00006: saving model to checkpoints\20191117_1315_model_weights.h5
# 5000/5000 [==============================] - 3260s 652ms/step - loss: 0.1976 - squared_angdiff_and_mse: 0.1976 - mae: 0.1548 - val_loss: 0.1999 - val_squared_angdiff_and_mse: 0.1999 - val_mae: 0.1812
# Epoch 7/20
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1606 - squared_angdiff_and_mse: 0.1606 - mae: 0.1362
# Epoch 00007: saving model to checkpoints\20191117_1315_model_weights.h5
# 5000/5000 [==============================] - 3269s 654ms/step - loss: 0.1606 - squared_angdiff_and_mse: 0.1606 - mae: 0.1362 - val_loss: 0.2168 - val_squared_angdiff_and_mse: 0.2168 - val_mae: 0.1577
# Epoch 8/20
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1578 - squared_angdiff_and_mse: 0.1578 - mae: 0.1329
# Epoch 00008: saving model to checkpoints\20191117_1315_model_weights.h5
# 5000/5000 [==============================] - 3255s 651ms/step - loss: 0.1578 - squared_angdiff_and_mse: 0.1578 - mae: 0.1329 - val_loss: 0.1404 - val_squared_angdiff_and_mse: 0.1404 - val_mae: 0.1490
# Epoch 9/20
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1459 - squared_angdiff_and_mse: 0.1459 - mae: 0.1294
# Epoch 00009: saving model to checkpoints\20191117_1315_model_weights.h5
# 5000/5000 [==============================] - 3290s 658ms/step - loss: 0.1459 - squared_angdiff_and_mse: 0.1459 - mae: 0.1294 - val_loss: 0.2505 - val_squared_angdiff_and_mse: 0.2505 - val_mae: 0.1565
# Epoch 10/20
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1379 - squared_angdiff_and_mse: 0.1379 - mae: 0.1262
# Epoch 00010: saving model to checkpoints\20191117_1315_model_weights.h5
# 5000/5000 [==============================] - 3329s 666ms/step - loss: 0.1378 - squared_angdiff_and_mse: 0.1378 - mae: 0.1262 - val_loss: 0.1604 - val_squared_angdiff_and_mse: 0.1604 - val_mae: 0.1459
# Epoch 11/20
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1418 - squared_angdiff_and_mse: 0.1418 - mae: 0.1254
# Epoch 00011: saving model to checkpoints\20191117_1315_model_weights.h5
# 5000/5000 [==============================] - 3259s 652ms/step - loss: 0.1418 - squared_angdiff_and_mse: 0.1418 - mae: 0.1254 - val_loss: 0.2747 - val_squared_angdiff_and_mse: 0.2747 - val_mae: 0.1388
# Epoch 12/20
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1443 - squared_angdiff_and_mse: 0.1443 - mae: 0.1244
# Epoch 00012: saving model to checkpoints\20191117_1315_model_weights.h5
# 5000/5000 [==============================] - 3250s 650ms/step - loss: 0.1442 - squared_angdiff_and_mse: 0.1442 - mae: 0.1244 - val_loss: 0.1626 - val_squared_angdiff_and_mse: 0.1626 - val_mae: 0.1349
# Epoch 13/20
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1364 - squared_angdiff_and_mse: 0.1364 - mae: 0.1218
# Epoch 00013: saving model to checkpoints\20191117_1315_model_weights.h5
# 5000/5000 [==============================] - 3247s 649ms/step - loss: 0.1364 - squared_angdiff_and_mse: 0.1364 - mae: 0.1218 - val_loss: 0.1225 - val_squared_angdiff_and_mse: 0.1225 - val_mae: 0.1393
# Epoch 14/20
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1367 - squared_angdiff_and_mse: 0.1367 - mae: 0.1207
# Epoch 00014: saving model to checkpoints\20191117_1315_model_weights.h5
# 5000/5000 [==============================] - 3368s 674ms/step - loss: 0.1367 - squared_angdiff_and_mse: 0.1367 - mae: 0.1207 - val_loss: 0.2631 - val_squared_angdiff_and_mse: 0.2631 - val_mae: 0.1543
# Epoch 15/20
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1283 - squared_angdiff_and_mse: 0.1283 - mae: 0.1177
# Epoch 00015: saving model to checkpoints\20191117_1315_model_weights.h5
# 5000/5000 [==============================] - 3257s 651ms/step - loss: 0.1283 - squared_angdiff_and_mse: 0.1283 - mae: 0.1177 - val_loss: 0.2361 - val_squared_angdiff_and_mse: 0.2361 - val_mae: 0.1801
# Epoch 16/20
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1265 - squared_angdiff_and_mse: 0.1265 - mae: 0.1150
# Epoch 00016: saving model to checkpoints\20191117_1315_model_weights.h5
# 5000/5000 [==============================] - 3244s 649ms/step - loss: 0.1265 - squared_angdiff_and_mse: 0.1265 - mae: 0.1150 - val_loss: 0.2483 - val_squared_angdiff_and_mse: 0.2483 - val_mae: 0.1354
# Epoch 17/20
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1352 - squared_angdiff_and_mse: 0.1352 - mae: 0.1154
# Epoch 00017: saving model to checkpoints\20191117_1315_model_weights.h5
# 5000/5000 [==============================] - 3332s 666ms/step - loss: 0.1352 - squared_angdiff_and_mse: 0.1352 - mae: 0.1154 - val_loss: 0.1204 - val_squared_angdiff_and_mse: 0.1204 - val_mae: 0.1170
# Epoch 18/20
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1276 - squared_angdiff_and_mse: 0.1276 - mae: 0.1124
# Epoch 00018: saving model to checkpoints\20191117_1315_model_weights.h5
# 5000/5000 [==============================] - 3289s 658ms/step - loss: 0.1276 - squared_angdiff_and_mse: 0.1276 - mae: 0.1124 - val_loss: 0.1353 - val_squared_angdiff_and_mse: 0.1353 - val_mae: 0.1237
# Epoch 19/20
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1207 - squared_angdiff_and_mse: 0.1207 - mae: 0.1097
# Epoch 00019: saving model to checkpoints\20191117_1315_model_weights.h5
# 5000/5000 [==============================] - 3244s 649ms/step - loss: 0.1206 - squared_angdiff_and_mse: 0.1206 - mae: 0.1097 - val_loss: 0.0989 - val_squared_angdiff_and_mse: 0.0989 - val_mae: 0.1135
# Epoch 20/20
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1321 - squared_angdiff_and_mse: 0.1321 - mae: 0.1105
# Epoch 00020: saving model to checkpoints\20191117_1315_model_weights.h5
# 5000/5000 [==============================] - 3254s 651ms/step - loss: 0.1321 - squared_angdiff_and_mse: 0.1321 - mae: 0.1105 - val_loss: 0.2595 - val_squared_angdiff_and_mse: 0.2595 - val_mae: 0.1641

# %% [markdown]
# Evaluation

# %%
model.evaluate_generator(generator=test_generator, steps= 625)
# Out:
# [0.21639828685447574, 0.21639824, 0.14449598]

# %% [markdown]
# Testing Results

# %%
test_generator.reset()
pred=model.predict_generator(test_generator, verbose=1)
filenames=test_generator.filenames
labels = []
for filename in filenames:
    labels.append('.'.join([filename.split('_')[1].split('.')[0], filename.split('_')[1].split('.')[1]]))
labels_f = [float(x) for x in labels]
pred_f = [float(x) for x in pred]
diff = []
for i in range(len(labels)):
    diff.append(pred_f[i]-labels_f[i]) 
results=pd.DataFrame({"Filename":filenames,
                      "Label": labels,
                      "Predictions":pred.tolist(),
                      "Difference": diff})
results.to_csv("results_train_{}.csv".format(SESSION_NAME),index=False)
results.head()
# Out:
# 625/625 [==============================] - 89s 142ms/step
#                       Filename Label           Predictions  Difference
# 0   1573560928.626884_0.05.png  0.05                 [0.0]   -0.050000
# 1  1573560928.8591487_0.15.png  0.15                 [0.0]   -0.150000
# 2  1573560929.0794158_0.22.png  0.22                 [0.0]   -0.220000
# 3   1573560929.3035173_0.3.png   0.3   [0.393441379070282]    0.093441
# 4  1573560929.5403802_0.37.png  0.37  [0.4477759599685669]    0.077776

# %%
model.save("17_11\model_{}.h5".format(SESSION_NAME))
model.save("17_11\model_{}".format(SESSION_NAME))
# Out:
# WARNING:tensorflow:From C:\Users\eduhunlau001\.conda\envs\tensorflow\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: 17_11\model_20191117_1315\assets

# %%
model.save_weights("17_11\model_weights_{}".format(SESSION_NAME))

# %%
# %tensorboard --logdir logs\20191117_1315
# Out:
# Reusing TensorBoard on port 6006 (pid 540), started 0:00:48 ago. (Use '!kill 540' to kill it.)
#       <iframe id="tensorboard-frame-2e81ac202de6702c" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-2e81ac202de6702c");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# # Erwartung
#
# das Modell underfittet durch die viel geringere Anzahl an Parameter
#
# # Ergebniss
# ---
