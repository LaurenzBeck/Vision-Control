# %%
import sys
assert sys.version_info >= (3, 5)

# %tensorflow_version 2.x
import tensorflow as tf 
from tensorflow import keras
assert tf.__version__ >= "2.0"

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

from time import time
import datetime

# %matplotlib inline
# %load_ext tensorboard

SEED = 42
SESSION_NAME = datetime.datetime.now().strftime("%Y%m%d_%H%M")
PI = tf.constant(np.pi)

print(SESSION_NAME)
# Out:
# 20200108_1016

# %% [markdown]
# Image Data

# %%
df_train=pd.read_csv("./labels_train.csv",dtype={'id': str, 'label': np.float32}, nrows = 20000)
df_val=pd.read_csv("./labels_val.csv",dtype={'id': str, 'label': np.float32})
df_test=pd.read_csv("./labels_test.csv",dtype={'id': str, 'label': np.float32})
IMG_PATH_TRAIN = "images_train/"
IMG_PATH_VAL = "images_val/"
IMG_PATH_TEST = "images_test/"

df_train.head()
# Out:
#                             id  label
# 0    1571743900.829366_0.1.png   0.10
# 1  1571743901.0525975_0.19.png   0.19
# 2  1571743901.2681353_0.28.png   0.28
# 3  1571743901.5050101_0.38.png   0.38
# 4  1571743901.7268791_0.46.png   0.46

# %% [markdown]
# Data Augmentation Pipeline

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

HEIGHT = 480
WIDTH = 640
TARGET_HEIGHT = 480
TARGET_WIDTH = 640
CHANNELS = 1
BATCH_SIZE = 16
NUM_TRAIN_IMAGES = 40000
NUM_VAL_IMAGES = 10000
NUM_TEST_IMAGES = 10000

datagen = ImageDataGenerator(rescale = 1/256,
                             width_shift_range = 25,
                             height_shift_range = 25,
                             rotation_range = 5,
                             brightness_range = [0.7, 1.3],
                             zoom_range = 0.25)

train_generator = datagen.flow_from_dataframe(dataframe=df_train,
                                              directory=IMG_PATH_TRAIN,
                                              x_col="id",
                                              y_col="label",
                                              seed=SEED,
                                              batch_size=BATCH_SIZE,
                                              shuffle=True,
                                              class_mode="raw",
                                              target_size=(TARGET_HEIGHT,TARGET_WIDTH),
                                              color_mode = "grayscale")

val_generator = datagen.flow_from_dataframe(dataframe=df_val,
                                            directory=IMG_PATH_VAL,
                                            x_col="id",
                                            y_col="label",
                                            seed=SEED,
                                            batch_size=BATCH_SIZE,
                                            shuffle=False,
                                            class_mode="raw",
                                            target_size=(TARGET_HEIGHT,TARGET_WIDTH),
                                            color_mode = "grayscale")

test_datagen = ImageDataGenerator(rescale = 1/256)

test_generator = test_datagen.flow_from_dataframe(dataframe=df_test,
                                                  directory=IMG_PATH_TEST,
                                                  x_col="id",
                                                  y_col="label",
                                                  batch_size=BATCH_SIZE,
                                                  class_mode="raw",
                                                  shuffle=False,
                                                  target_size=(TARGET_HEIGHT,TARGET_WIDTH),
                                                  color_mode = "grayscale")

fig = plt.figure(figsize=(12,10))
for X_batch, y_batch in train_generator:
    for i in range(1, 9):
        image = ((X_batch[i-1]*256).astype('uint8'))[:,:,0]
        a = fig.add_subplot(4, 2, i)
        imgplot = plt.imshow(image, cmap='gray', vmin = 0, vmax = 256)
        a.set_title("{}".format(i))
        plt.tight_layout()
    break
# Out:
# Found 20000 validated image filenames.
# Found 10000 validated image filenames.
# Found 10000 validated image filenames.

# %% [markdown]
# Model Definition

# %%
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization, Conv2D, MaxPooling2D
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2

model = keras.models.Sequential([
    keras.layers.Conv2D(32, 7, activation="elu", padding="same", kernel_initializer="he_normal",
                        input_shape=[TARGET_HEIGHT,TARGET_WIDTH,CHANNELS]),
    keras.layers.Conv2D(32, 3, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.BatchNormalization(),
    keras.layers.AveragePooling2D(pool_size=2),
    keras.layers.Conv2D(16, 1, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.Conv2D(32, 3, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.BatchNormalization(),
    keras.layers.AveragePooling2D(pool_size=2),
    keras.layers.Conv2D(16, 1, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.Conv2D(32, 3, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.BatchNormalization(),
    keras.layers.AveragePooling2D(pool_size=2),
    keras.layers.Conv2D(32, 1, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.Conv2D(64, 3, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.BatchNormalization(),
    keras.layers.AveragePooling2D(pool_size=2),
    keras.layers.Conv2D(32, 1, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.Conv2D(64, 3, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.BatchNormalization(),
    keras.layers.AveragePooling2D(pool_size=2),
    keras.layers.Conv2D(64, 1, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.Conv2D(128, 3, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.BatchNormalization(),
    keras.layers.AveragePooling2D(pool_size=2),
    keras.layers.Conv2D(64, 1, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.Conv2D(128, 3, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.BatchNormalization(),
    keras.layers.GlobalAvgPool2D(),
    keras.layers.Flatten(),
    keras.layers.Dense(32, activation="elu"),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(16, activation="elu"),
    keras.layers.Dense(1, activation="relu")
])

model.summary()

#tf.keras.utils.plot_model(
#    model,
#    to_file='model.png',
#    show_shapes=True,
#    show_layer_names=True,
#    rankdir='TB',
#    expand_nested=False,
#    dpi=96
#)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 480, 640, 32)      1600
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 480, 640, 32)      9248
# _________________________________________________________________
# batch_normalization (BatchNo (None, 480, 640, 32)      128
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 240, 320, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 240, 320, 16)      528
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 240, 320, 32)      4640
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 240, 320, 32)      128
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 120, 160, 32)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 120, 160, 16)      528
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 120, 160, 32)      4640
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 120, 160, 32)      128
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 60, 80, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 60, 80, 32)        1056
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 60, 80, 64)        18496
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 60, 80, 64)        256
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 30, 40, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 30, 40, 32)        2080
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 30, 40, 64)        18496
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 30, 40, 64)        256
# _________________________________________________________________
# average_pooling2d_4 (Average (None, 15, 20, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 15, 20, 64)        4160
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 15, 20, 128)       73856
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 15, 20, 128)       512
# _________________________________________________________________
# average_pooling2d_5 (Average (None, 7, 10, 128)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 7, 10, 64)         8256
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 7, 10, 128)        73856
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 7, 10, 128)        512
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                4128
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 228,033
# Trainable params: 227,073
# Non-trainable params: 960
# _________________________________________________________________

# %% [markdown]
# Loss and Compilation

# %%
def squared_angdiff_and_mse(y_true, y_pred):
    squared_angdiff = tf.square( tf.atan2(tf.sin(y_pred - y_true), tf.cos(y_pred - y_true)) )
    mse = tf.square(y_pred - y_true)
    loss = tf.add(squared_angdiff, mse)
    return loss

def scheduler(epoch):
  if epoch < 3:
    return 0.004
  elif epoch < 6:
    return 0.002
  elif epoch < 20:
    return 0.001
  elif epoch < 30:
    return 0.0008
  else:
    return 0.0005

schedule = keras.callbacks.LearningRateScheduler(scheduler)

FILEPATH_SAVE='checkpoints\{}_model_weights.h5'.format(SESSION_NAME)
checkpoint = keras.callbacks.ModelCheckpoint(FILEPATH_SAVE,
                                             monitor=[squared_angdiff_and_mse],
                                             verbose=1,
                                             mode='min')

FILEPATH_TENSORBOARD_LOG = 'logs\{}'.format(SESSION_NAME)
tensorboard = keras.callbacks.TensorBoard(log_dir = FILEPATH_TENSORBOARD_LOG,
                                          histogram_freq=1,
                                          write_graph=True,
                                          write_images=True,
                                          update_freq=10000,
                                         )

model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.01,
                                                         beta_1=0.9,
                                                         beta_2=0.95,
                                                         epsilon=1e-07,
                                                         ),
              loss=squared_angdiff_and_mse,
              metrics=[squared_angdiff_and_mse, 'mae'])

# %% [markdown]
# Training

# %%
# Training constants
NUM_EPOCHS = 32

history = model.fit_generator(generator=train_generator, 
                              validation_data=val_generator,
                              validation_steps=625,
                              steps_per_epoch=5000,
                              epochs=NUM_EPOCHS,
                              callbacks=[tensorboard, checkpoint, schedule])
# Out:
# Epoch 1/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 1.2114 - squared_angdiff_and_mse: 1.2114 - mae: 0.4516
# Epoch 00001: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2723s 545ms/step - loss: 1.2112 - squared_angdiff_and_mse: 1.2112 - mae: 0.4516 - val_loss: 0.3423 - val_squared_angdiff_and_mse: 0.3423 - val_mae: 0.2193
# Epoch 2/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.3574 - squared_angdiff_and_mse: 0.3574 - mae: 0.2282
# Epoch 00002: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2602s 520ms/step - loss: 0.3574 - squared_angdiff_and_mse: 0.3574 - mae: 0.2281 - val_loss: 0.2463 - val_squared_angdiff_and_mse: 0.2463 - val_mae: 0.1884
# Epoch 3/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.2890 - squared_angdiff_and_mse: 0.2890 - mae: 0.1968
# Epoch 00003: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2597s 519ms/step - loss: 0.2889 - squared_angdiff_and_mse: 0.2889 - mae: 0.1968 - val_loss: 0.2282 - val_squared_angdiff_and_mse: 0.2282 - val_mae: 0.1724
# Epoch 4/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1718 - squared_angdiff_and_mse: 0.1718 - mae: 0.1451
# Epoch 00004: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2600s 520ms/step - loss: 0.1717 - squared_angdiff_and_mse: 0.1717 - mae: 0.1451 - val_loss: 0.2911 - val_squared_angdiff_and_mse: 0.2911 - val_mae: 0.1918
# Epoch 5/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1507 - squared_angdiff_and_mse: 0.1507 - mae: 0.1340
# Epoch 00005: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2594s 519ms/step - loss: 0.1506 - squared_angdiff_and_mse: 0.1506 - mae: 0.1340 - val_loss: 0.2661 - val_squared_angdiff_and_mse: 0.2661 - val_mae: 0.1314
# Epoch 6/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1420 - squared_angdiff_and_mse: 0.1420 - mae: 0.1282
# Epoch 00006: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2558s 512ms/step - loss: 0.1420 - squared_angdiff_and_mse: 0.1420 - mae: 0.1282 - val_loss: 0.1506 - val_squared_angdiff_and_mse: 0.1506 - val_mae: 0.1002
# Epoch 7/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0960 - squared_angdiff_and_mse: 0.0960 - mae: 0.1048
# Epoch 00007: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2574s 515ms/step - loss: 0.0960 - squared_angdiff_and_mse: 0.0960 - mae: 0.1048 - val_loss: 0.2149 - val_squared_angdiff_and_mse: 0.2149 - val_mae: 0.1592
# Epoch 8/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0988 - squared_angdiff_and_mse: 0.0988 - mae: 0.1019
# Epoch 00008: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2687s 537ms/step - loss: 0.0988 - squared_angdiff_and_mse: 0.0988 - mae: 0.1019 - val_loss: 0.1464 - val_squared_angdiff_and_mse: 0.1464 - val_mae: 0.1248
# Epoch 9/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0906 - squared_angdiff_and_mse: 0.0906 - mae: 0.0979
# Epoch 00009: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2552s 510ms/step - loss: 0.0906 - squared_angdiff_and_mse: 0.0906 - mae: 0.0979 - val_loss: 0.1419 - val_squared_angdiff_and_mse: 0.1419 - val_mae: 0.1311
# Epoch 10/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0959 - squared_angdiff_and_mse: 0.0959 - mae: 0.0968
# Epoch 00010: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2558s 512ms/step - loss: 0.0958 - squared_angdiff_and_mse: 0.0958 - mae: 0.0968 - val_loss: 0.2018 - val_squared_angdiff_and_mse: 0.2018 - val_mae: 0.1689
# Epoch 11/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0895 - squared_angdiff_and_mse: 0.0895 - mae: 0.0924
# Epoch 00011: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2541s 508ms/step - loss: 0.0895 - squared_angdiff_and_mse: 0.0895 - mae: 0.0924 - val_loss: 0.1890 - val_squared_angdiff_and_mse: 0.1890 - val_mae: 0.1785
# Epoch 12/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0853 - squared_angdiff_and_mse: 0.0853 - mae: 0.0910
# Epoch 00012: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2547s 509ms/step - loss: 0.0853 - squared_angdiff_and_mse: 0.0853 - mae: 0.0910 - val_loss: 0.1563 - val_squared_angdiff_and_mse: 0.1563 - val_mae: 0.1618
# Epoch 13/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0915 - squared_angdiff_and_mse: 0.0915 - mae: 0.0897
# Epoch 00013: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2603s 521ms/step - loss: 0.0915 - squared_angdiff_and_mse: 0.0915 - mae: 0.0897 - val_loss: 0.2072 - val_squared_angdiff_and_mse: 0.2072 - val_mae: 0.1592
# Epoch 14/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0910 - squared_angdiff_and_mse: 0.0910 - mae: 0.0895
# Epoch 00014: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2602s 520ms/step - loss: 0.0910 - squared_angdiff_and_mse: 0.0910 - mae: 0.0895 - val_loss: 0.1718 - val_squared_angdiff_and_mse: 0.1718 - val_mae: 0.1553
# Epoch 15/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0736 - squared_angdiff_and_mse: 0.0736 - mae: 0.0844
# Epoch 00015: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2552s 510ms/step - loss: 0.0735 - squared_angdiff_and_mse: 0.0735 - mae: 0.0844 - val_loss: 0.2452 - val_squared_angdiff_and_mse: 0.2452 - val_mae: 0.1866
# Epoch 16/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0791 - squared_angdiff_and_mse: 0.0791 - mae: 0.0843
# Epoch 00016: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2563s 513ms/step - loss: 0.0791 - squared_angdiff_and_mse: 0.0791 - mae: 0.0843 - val_loss: 0.2669 - val_squared_angdiff_and_mse: 0.2669 - val_mae: 0.1963
# Epoch 17/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0802 - squared_angdiff_and_mse: 0.0802 - mae: 0.0838
# Epoch 00017: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2557s 511ms/step - loss: 0.0802 - squared_angdiff_and_mse: 0.0802 - mae: 0.0838 - val_loss: 0.2760 - val_squared_angdiff_and_mse: 0.2760 - val_mae: 0.1927
# Epoch 18/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0702 - squared_angdiff_and_mse: 0.0702 - mae: 0.0816
# Epoch 00018: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2555s 511ms/step - loss: 0.0702 - squared_angdiff_and_mse: 0.0702 - mae: 0.0816 - val_loss: 0.2316 - val_squared_angdiff_and_mse: 0.2316 - val_mae: 0.1775
# Epoch 19/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0715 - squared_angdiff_and_mse: 0.0715 - mae: 0.0797
# Epoch 00019: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2555s 511ms/step - loss: 0.0715 - squared_angdiff_and_mse: 0.0715 - mae: 0.0797 - val_loss: 0.2128 - val_squared_angdiff_and_mse: 0.2128 - val_mae: 0.1958
# Epoch 20/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0757 - squared_angdiff_and_mse: 0.0757 - mae: 0.0805
# Epoch 00020: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2557s 511ms/step - loss: 0.0757 - squared_angdiff_and_mse: 0.0757 - mae: 0.0805 - val_loss: 0.2592 - val_squared_angdiff_and_mse: 0.2592 - val_mae: 0.1918
# Epoch 21/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0718 - squared_angdiff_and_mse: 0.0718 - mae: 0.0766
# Epoch 00021: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2645s 529ms/step - loss: 0.0718 - squared_angdiff_and_mse: 0.0718 - mae: 0.0766 - val_loss: 0.1674 - val_squared_angdiff_and_mse: 0.1674 - val_mae: 0.1634
# Epoch 22/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0668 - squared_angdiff_and_mse: 0.0668 - mae: 0.0749
# Epoch 00022: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2549s 510ms/step - loss: 0.0668 - squared_angdiff_and_mse: 0.0668 - mae: 0.0749 - val_loss: 0.1973 - val_squared_angdiff_and_mse: 0.1973 - val_mae: 0.1734
# Epoch 23/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0685 - squared_angdiff_and_mse: 0.0685 - mae: 0.0736
# Epoch 00023: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2551s 510ms/step - loss: 0.0685 - squared_angdiff_and_mse: 0.0685 - mae: 0.0736 - val_loss: 0.2143 - val_squared_angdiff_and_mse: 0.2143 - val_mae: 0.1873
# Epoch 24/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0646 - squared_angdiff_and_mse: 0.0646 - mae: 0.0728
# Epoch 00024: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2546s 509ms/step - loss: 0.0649 - squared_angdiff_and_mse: 0.0649 - mae: 0.0729 - val_loss: 0.2523 - val_squared_angdiff_and_mse: 0.2523 - val_mae: 0.2180
# Epoch 25/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0745 - squared_angdiff_and_mse: 0.0745 - mae: 0.0745
# Epoch 00025: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2665s 533ms/step - loss: 0.0745 - squared_angdiff_and_mse: 0.0745 - mae: 0.0745 - val_loss: 0.2185 - val_squared_angdiff_and_mse: 0.2185 - val_mae: 0.1869
# Epoch 26/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0618 - squared_angdiff_and_mse: 0.0618 - mae: 0.0710
# Epoch 00026: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2557s 511ms/step - loss: 0.0618 - squared_angdiff_and_mse: 0.0618 - mae: 0.0710 - val_loss: 0.3150 - val_squared_angdiff_and_mse: 0.3150 - val_mae: 0.2117
# Epoch 27/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0608 - squared_angdiff_and_mse: 0.0608 - mae: 0.0696
# Epoch 00027: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2550s 510ms/step - loss: 0.0608 - squared_angdiff_and_mse: 0.0608 - mae: 0.0696 - val_loss: 0.2283 - val_squared_angdiff_and_mse: 0.2283 - val_mae: 0.1863
# Epoch 28/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0653 - squared_angdiff_and_mse: 0.0653 - mae: 0.0711
# Epoch 00028: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2550s 510ms/step - loss: 0.0653 - squared_angdiff_and_mse: 0.0653 - mae: 0.0711 - val_loss: 0.2647 - val_squared_angdiff_and_mse: 0.2647 - val_mae: 0.2348
# Epoch 29/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0676 - squared_angdiff_and_mse: 0.0676 - mae: 0.0697
# Epoch 00029: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2559s 512ms/step - loss: 0.0675 - squared_angdiff_and_mse: 0.0675 - mae: 0.0697 - val_loss: 0.2331 - val_squared_angdiff_and_mse: 0.2331 - val_mae: 0.1892
# Epoch 30/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0638 - squared_angdiff_and_mse: 0.0638 - mae: 0.0692
# Epoch 00030: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2556s 511ms/step - loss: 0.0638 - squared_angdiff_and_mse: 0.0638 - mae: 0.0692 - val_loss: 0.3499 - val_squared_angdiff_and_mse: 0.3499 - val_mae: 0.2342
# Epoch 31/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0567 - squared_angdiff_and_mse: 0.0567 - mae: 0.0638
# Epoch 00031: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2656s 531ms/step - loss: 0.0567 - squared_angdiff_and_mse: 0.0567 - mae: 0.0638 - val_loss: 0.2389 - val_squared_angdiff_and_mse: 0.2389 - val_mae: 0.2114
# Epoch 32/32
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0490 - squared_angdiff_and_mse: 0.0490 - mae: 0.0614
# Epoch 00032: saving model to checkpoints\20200108_1016_model_weights.h5
# 5000/5000 [==============================] - 2553s 511ms/step - loss: 0.0495 - squared_angdiff_and_mse: 0.0495 - mae: 0.0615 - val_loss: 0.2882 - val_squared_angdiff_and_mse: 0.2882 - val_mae: 0.2233

# %% [markdown]
# Evaluation

# %%
model.evaluate_generator(generator=test_generator, steps= 625)
# Out:
# [0.2189156540482305, 0.21891555, 0.2162801]

# %% [markdown]
# Testing Results

# %%
test_generator.reset()
pred=model.predict_generator(test_generator, verbose=1)
filenames=test_generator.filenames
labels = []
for filename in filenames:
    labels.append('.'.join([filename.split('_')[1].split('.')[0], filename.split('_')[1].split('.')[1]]))
labels_f = [float(x) for x in labels]
pred_f = [float(x) for x in pred]
diff = []
for i in range(len(labels)):
    diff.append(pred_f[i]-labels_f[i]) 
results=pd.DataFrame({"Filename":filenames,
                      "Label": labels,
                      "Predictions":pred.tolist(),
                      "Difference": diff})
results.to_csv("results_train_{}.csv".format(SESSION_NAME),index=False)
results.head()
# Out:
# 625/625 [==============================] - 91s 146ms/step
#                       Filename Label           Predictions  Difference
# 0   1573560928.626884_0.05.png  0.05                 [0.0]   -0.050000
# 1  1573560928.8591487_0.15.png  0.15   [0.561531662940979]    0.411532
# 2  1573560929.0794158_0.22.png  0.22  [0.5982745885848999]    0.378275
# 3   1573560929.3035173_0.3.png   0.3  [0.6831805109977722]    0.383181
# 4  1573560929.5403802_0.37.png  0.37  [0.7528606057167053]    0.382861

# %%
model.save("8_1\model_{}.h5".format(SESSION_NAME))
model.save("8_1\model_{}".format(SESSION_NAME))
# Out:
# WARNING:tensorflow:From C:\Users\eduhunlau001\.conda\envs\tensorflow\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: 8_1\model_20200108_1016\assets

# %%
model.save_weights("8_1\model_weights_{}".format(SESSION_NAME))

# %%
# %tensorboard --logdir logs\20191113_1029
# Out:
# ERROR: Timed out waiting for TensorBoard to start. It may still be running as pid 24464.

# %% [markdown]
# # Ergebniss
# ---
# + Regebnisse positiv!
# + Bei dem Scheduling programm starke verbesserung bis ca epoche 5 und ab 10 nochmal schwächer. D.h. bei kleineren Modelluntersuchungen sollten 5 Epochen reichen.
# + weder high bias, noch high variance!
# + performance muss noch gemessen werden.
