# %%
import sys
assert sys.version_info >= (3, 5)

# %tensorflow_version 2.x
import tensorflow as tf 
from tensorflow import keras
assert tf.__version__ >= "2.0"

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

from time import time
import datetime

# %matplotlib inline
# %load_ext tensorboard

SEED = 42
SESSION_NAME = datetime.datetime.now().strftime("%Y%m%d_%H%M")
PI = tf.constant(np.pi)

print(SESSION_NAME)
# Out:
# 20200109_1045

# %% [markdown]
# Image Data

# %%
df_train=pd.read_csv("./labels_train.csv",dtype={'id': str, 'label': np.float32}, nrows = 10000)
df_val=pd.read_csv("./labels_val.csv",dtype={'id': str, 'label': np.float32})
df_test=pd.read_csv("./labels_test.csv",dtype={'id': str, 'label': np.float32})
IMG_PATH_TRAIN = "images_train/"
IMG_PATH_VAL = "images_val/"
IMG_PATH_TEST = "images_test/"

df_train.head()
# Out:
#                             id  label
# 0    1571743900.829366_0.1.png   0.10
# 1  1571743901.0525975_0.19.png   0.19
# 2  1571743901.2681353_0.28.png   0.28
# 3  1571743901.5050101_0.38.png   0.38
# 4  1571743901.7268791_0.46.png   0.46

# %% [markdown]
# Data Augmentation Pipeline

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

HEIGHT = 480
WIDTH = 640
TARGET_HEIGHT = 480
TARGET_WIDTH = 640
CHANNELS = 1
BATCH_SIZE = 16
NUM_TRAIN_IMAGES = 40000
NUM_VAL_IMAGES = 10000
NUM_TEST_IMAGES = 10000

datagen = ImageDataGenerator(rescale = 1/256,
                             width_shift_range = 25,
                             height_shift_range = 25,
                             rotation_range = 5,
                             brightness_range = [0.7, 1.3],
                             zoom_range = 0.25)

train_generator = datagen.flow_from_dataframe(dataframe=df_train,
                                              directory=IMG_PATH_TRAIN,
                                              x_col="id",
                                              y_col="label",
                                              seed=SEED,
                                              batch_size=BATCH_SIZE,
                                              shuffle=True,
                                              class_mode="raw",
                                              target_size=(TARGET_HEIGHT,TARGET_WIDTH),
                                              color_mode = "grayscale")

val_generator = datagen.flow_from_dataframe(dataframe=df_val,
                                            directory=IMG_PATH_VAL,
                                            x_col="id",
                                            y_col="label",
                                            seed=SEED,
                                            batch_size=BATCH_SIZE,
                                            shuffle=False,
                                            class_mode="raw",
                                            target_size=(TARGET_HEIGHT,TARGET_WIDTH),
                                            color_mode = "grayscale")

test_datagen = ImageDataGenerator(rescale = 1/256)

test_generator = test_datagen.flow_from_dataframe(dataframe=df_test,
                                                  directory=IMG_PATH_TEST,
                                                  x_col="id",
                                                  y_col="label",
                                                  batch_size=BATCH_SIZE,
                                                  class_mode="raw",
                                                  shuffle=False,
                                                  target_size=(TARGET_HEIGHT,TARGET_WIDTH),
                                                  color_mode = "grayscale")

fig = plt.figure(figsize=(12,10))
for X_batch, y_batch in train_generator:
    for i in range(1, 9):
        image = ((X_batch[i-1]*256).astype('uint8'))[:,:,0]
        a = fig.add_subplot(4, 2, i)
        imgplot = plt.imshow(image, cmap='gray', vmin = 0, vmax = 256)
        a.set_title("{}".format(i))
        plt.tight_layout()
    break
# Out:
# Found 10000 validated image filenames.
# Found 10000 validated image filenames.
# Found 10000 validated image filenames.

# %% [markdown]
# Model Definition

# %%
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization, Conv2D, MaxPooling2D
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2

model = keras.models.Sequential([
    keras.layers.Conv2D(32, 7, activation="elu", padding="same", kernel_initializer="he_normal",
                        input_shape=[TARGET_HEIGHT,TARGET_WIDTH,CHANNELS]),
    keras.layers.Conv2D(32, 3, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.BatchNormalization(),
    keras.layers.AveragePooling2D(pool_size=2),
    keras.layers.Conv2D(16, 1, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.Conv2D(32, 3, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.BatchNormalization(),
    keras.layers.AveragePooling2D(pool_size=2),
    keras.layers.Conv2D(16, 1, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.Conv2D(32, 3, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.BatchNormalization(),
    keras.layers.AveragePooling2D(pool_size=2),
    keras.layers.Conv2D(32, 1, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.Conv2D(64, 3, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.BatchNormalization(),
    keras.layers.AveragePooling2D(pool_size=2),
    keras.layers.Conv2D(32, 1, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.Conv2D(64, 3, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.BatchNormalization(),
    keras.layers.AveragePooling2D(pool_size=2),
    keras.layers.Conv2D(64, 1, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.Conv2D(128, 3, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.BatchNormalization(),
    keras.layers.AveragePooling2D(pool_size=2),
    keras.layers.Conv2D(64, 1, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.Conv2D(128, 3, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.BatchNormalization(),
    keras.layers.GlobalAvgPool2D(),
    keras.layers.Flatten(),
    keras.layers.Dense(32, activation="elu"),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(16, activation="elu"),
    keras.layers.Dense(1, activation="relu")
])

model.summary()

#tf.keras.utils.plot_model(
#    model,
#    to_file='model.png',
#    show_shapes=True,
#    show_layer_names=True,
#    rankdir='TB',
#    expand_nested=False,
#    dpi=96
#)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 480, 640, 32)      1600
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 480, 640, 32)      9248
# _________________________________________________________________
# batch_normalization (BatchNo (None, 480, 640, 32)      128
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 240, 320, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 240, 320, 16)      528
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 240, 320, 32)      4640
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 240, 320, 32)      128
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 120, 160, 32)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 120, 160, 16)      528
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 120, 160, 32)      4640
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 120, 160, 32)      128
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 60, 80, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 60, 80, 32)        1056
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 60, 80, 64)        18496
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 60, 80, 64)        256
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 30, 40, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 30, 40, 32)        2080
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 30, 40, 64)        18496
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 30, 40, 64)        256
# _________________________________________________________________
# average_pooling2d_4 (Average (None, 15, 20, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 15, 20, 64)        4160
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 15, 20, 128)       73856
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 15, 20, 128)       512
# _________________________________________________________________
# average_pooling2d_5 (Average (None, 7, 10, 128)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 7, 10, 64)         8256
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 7, 10, 128)        73856
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 7, 10, 128)        512
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                4128
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 228,033
# Trainable params: 227,073
# Non-trainable params: 960
# _________________________________________________________________

# %% [markdown]
# Loss and Compilation

# %%
def squared_angdiff_and_mse(y_true, y_pred):
    squared_angdiff = tf.square( tf.atan2(tf.sin(y_pred - y_true), tf.cos(y_pred - y_true)) )
    mse = tf.square(y_pred - y_true)
    loss = tf.add(squared_angdiff, mse)
    return loss

def scheduler(epoch):
  if epoch < 3:
    return 0.004
  elif epoch < 6:
    return 0.002
  elif epoch < 20:
    return 0.001
  elif epoch < 30:
    return 0.0008
  else:
    return 0.0005

schedule = keras.callbacks.LearningRateScheduler(scheduler)

FILEPATH_SAVE='checkpoints\{}_model_weights.h5'.format(SESSION_NAME)
checkpoint = keras.callbacks.ModelCheckpoint(FILEPATH_SAVE,
                                             monitor=[squared_angdiff_and_mse],
                                             verbose=1,
                                             mode='min')

FILEPATH_TENSORBOARD_LOG = 'logs\{}'.format(SESSION_NAME)
tensorboard = keras.callbacks.TensorBoard(log_dir = FILEPATH_TENSORBOARD_LOG,
                                          histogram_freq=1,
                                          write_graph=True,
                                          write_images=True,
                                          update_freq=10000,
                                         )

model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.01,
                                                         beta_1=0.9,
                                                         beta_2=0.95,
                                                         epsilon=1e-07,
                                                         ),
              loss=squared_angdiff_and_mse,
              metrics=[squared_angdiff_and_mse, 'mae'])

# %% [markdown]
# Training

# %%
# Training constants
NUM_EPOCHS = 64

history = model.fit_generator(generator=train_generator, 
                              validation_data=val_generator,
                              validation_steps=625,
                              steps_per_epoch=5000,
                              epochs=NUM_EPOCHS,
                              callbacks=[tensorboard, checkpoint, schedule])
# Out:
# Epoch 1/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 1.3898 - squared_angdiff_and_mse: 1.3898 - mae: 0.4931
# Epoch 00001: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2622s 524ms/step - loss: 1.3895 - squared_angdiff_and_mse: 1.3895 - mae: 0.4930 - val_loss: 0.9747 - val_squared_angdiff_and_mse: 0.9747 - val_mae: 0.4235
# Epoch 2/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.4147 - squared_angdiff_and_mse: 0.4147 - mae: 0.2355
# Epoch 00002: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2582s 516ms/step - loss: 0.4146 - squared_angdiff_and_mse: 0.4146 - mae: 0.2355 - val_loss: 0.9934 - val_squared_angdiff_and_mse: 0.9934 - val_mae: 0.4058
# Epoch 3/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.3197 - squared_angdiff_and_mse: 0.3197 - mae: 0.1967
# Epoch 00003: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2560s 512ms/step - loss: 0.3197 - squared_angdiff_and_mse: 0.3197 - mae: 0.1967 - val_loss: 0.8092 - val_squared_angdiff_and_mse: 0.8092 - val_mae: 0.3575
# Epoch 4/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1818 - squared_angdiff_and_mse: 0.1818 - mae: 0.1432
# Epoch 00004: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2562s 512ms/step - loss: 0.1817 - squared_angdiff_and_mse: 0.1817 - mae: 0.1432 - val_loss: 0.2645 - val_squared_angdiff_and_mse: 0.2645 - val_mae: 0.1527
# Epoch 5/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1724 - squared_angdiff_and_mse: 0.1724 - mae: 0.1336
# Epoch 00005: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2631s 526ms/step - loss: 0.1724 - squared_angdiff_and_mse: 0.1724 - mae: 0.1336 - val_loss: 0.3391 - val_squared_angdiff_and_mse: 0.3391 - val_mae: 0.1818
# Epoch 6/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1640 - squared_angdiff_and_mse: 0.1640 - mae: 0.1260
# Epoch 00006: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2547s 509ms/step - loss: 0.1640 - squared_angdiff_and_mse: 0.1640 - mae: 0.1260 - val_loss: 0.4777 - val_squared_angdiff_and_mse: 0.4777 - val_mae: 0.2629
# Epoch 7/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1159 - squared_angdiff_and_mse: 0.1159 - mae: 0.1043
# Epoch 00007: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2549s 510ms/step - loss: 0.1159 - squared_angdiff_and_mse: 0.1159 - mae: 0.1043 - val_loss: 0.1828 - val_squared_angdiff_and_mse: 0.1828 - val_mae: 0.1472
# Epoch 8/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1096 - squared_angdiff_and_mse: 0.1096 - mae: 0.0978
# Epoch 00008: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2569s 514ms/step - loss: 0.1096 - squared_angdiff_and_mse: 0.1096 - mae: 0.0978 - val_loss: 0.3053 - val_squared_angdiff_and_mse: 0.3053 - val_mae: 0.1529
# Epoch 9/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1047 - squared_angdiff_and_mse: 0.1047 - mae: 0.0948
# Epoch 00009: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2557s 511ms/step - loss: 0.1051 - squared_angdiff_and_mse: 0.1051 - mae: 0.0949 - val_loss: 0.3015 - val_squared_angdiff_and_mse: 0.3015 - val_mae: 0.1567
# Epoch 10/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1007 - squared_angdiff_and_mse: 0.1007 - mae: 0.0928
# Epoch 00010: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2626s 525ms/step - loss: 0.1007 - squared_angdiff_and_mse: 0.1007 - mae: 0.0927 - val_loss: 0.3393 - val_squared_angdiff_and_mse: 0.3393 - val_mae: 0.1815
# Epoch 11/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0954 - squared_angdiff_and_mse: 0.0954 - mae: 0.0901
# Epoch 00011: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2553s 511ms/step - loss: 0.0954 - squared_angdiff_and_mse: 0.0954 - mae: 0.0901 - val_loss: 0.2884 - val_squared_angdiff_and_mse: 0.2884 - val_mae: 0.1624
# Epoch 12/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0938 - squared_angdiff_and_mse: 0.0938 - mae: 0.0885
# Epoch 00012: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2566s 513ms/step - loss: 0.0938 - squared_angdiff_and_mse: 0.0938 - mae: 0.0885 - val_loss: 0.3234 - val_squared_angdiff_and_mse: 0.3234 - val_mae: 0.1673
# Epoch 13/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0892 - squared_angdiff_and_mse: 0.0892 - mae: 0.0866
# Epoch 00013: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2556s 511ms/step - loss: 0.0895 - squared_angdiff_and_mse: 0.0895 - mae: 0.0867 - val_loss: 0.4236 - val_squared_angdiff_and_mse: 0.4236 - val_mae: 0.1818
# Epoch 14/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0792 - squared_angdiff_and_mse: 0.0792 - mae: 0.0846
# Epoch 00014: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2552s 510ms/step - loss: 0.0792 - squared_angdiff_and_mse: 0.0792 - mae: 0.0846 - val_loss: 0.2136 - val_squared_angdiff_and_mse: 0.2136 - val_mae: 0.1453
# Epoch 15/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0840 - squared_angdiff_and_mse: 0.0840 - mae: 0.0844
# Epoch 00015: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2553s 511ms/step - loss: 0.0840 - squared_angdiff_and_mse: 0.0840 - mae: 0.0844 - val_loss: 0.3142 - val_squared_angdiff_and_mse: 0.3142 - val_mae: 0.2083
# Epoch 16/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0956 - squared_angdiff_and_mse: 0.0956 - mae: 0.0853
# Epoch 00016: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2569s 514ms/step - loss: 0.0956 - squared_angdiff_and_mse: 0.0956 - mae: 0.0853 - val_loss: 0.2376 - val_squared_angdiff_and_mse: 0.2376 - val_mae: 0.1551
# Epoch 17/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0797 - squared_angdiff_and_mse: 0.0797 - mae: 0.0826
# Epoch 00017: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2631s 526ms/step - loss: 0.0797 - squared_angdiff_and_mse: 0.0797 - mae: 0.0826 - val_loss: 0.2307 - val_squared_angdiff_and_mse: 0.2307 - val_mae: 0.1640
# Epoch 18/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0801 - squared_angdiff_and_mse: 0.0801 - mae: 0.0812
# Epoch 00018: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2552s 510ms/step - loss: 0.0800 - squared_angdiff_and_mse: 0.0800 - mae: 0.0812 - val_loss: 0.3434 - val_squared_angdiff_and_mse: 0.3434 - val_mae: 0.1665
# Epoch 19/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0874 - squared_angdiff_and_mse: 0.0874 - mae: 0.0825
# Epoch 00019: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2563s 513ms/step - loss: 0.0874 - squared_angdiff_and_mse: 0.0874 - mae: 0.0825 - val_loss: 0.2846 - val_squared_angdiff_and_mse: 0.2846 - val_mae: 0.1749
# Epoch 20/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0719 - squared_angdiff_and_mse: 0.0719 - mae: 0.0779
# Epoch 00020: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2572s 514ms/step - loss: 0.0719 - squared_angdiff_and_mse: 0.0719 - mae: 0.0779 - val_loss: 0.2953 - val_squared_angdiff_and_mse: 0.2953 - val_mae: 0.1752
# Epoch 21/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0670 - squared_angdiff_and_mse: 0.0670 - mae: 0.0749
# Epoch 00021: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2561s 512ms/step - loss: 0.0670 - squared_angdiff_and_mse: 0.0670 - mae: 0.0749 - val_loss: 0.3602 - val_squared_angdiff_and_mse: 0.3602 - val_mae: 0.1800
# Epoch 22/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0722 - squared_angdiff_and_mse: 0.0722 - mae: 0.0752
# Epoch 00022: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2562s 512ms/step - loss: 0.0722 - squared_angdiff_and_mse: 0.0722 - mae: 0.0752 - val_loss: 0.2256 - val_squared_angdiff_and_mse: 0.2256 - val_mae: 0.1650
# Epoch 23/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0721 - squared_angdiff_and_mse: 0.0721 - mae: 0.0743
# Epoch 00023: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2564s 513ms/step - loss: 0.0721 - squared_angdiff_and_mse: 0.0721 - mae: 0.0743 - val_loss: 0.3785 - val_squared_angdiff_and_mse: 0.3785 - val_mae: 0.1835
# Epoch 24/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0727 - squared_angdiff_and_mse: 0.0727 - mae: 0.0733
# Epoch 00024: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2644s 529ms/step - loss: 0.0727 - squared_angdiff_and_mse: 0.0727 - mae: 0.0733 - val_loss: 0.4415 - val_squared_angdiff_and_mse: 0.4415 - val_mae: 0.1814
# Epoch 25/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0713 - squared_angdiff_and_mse: 0.0713 - mae: 0.0734
# Epoch 00025: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2563s 513ms/step - loss: 0.0713 - squared_angdiff_and_mse: 0.0713 - mae: 0.0734 - val_loss: 0.3526 - val_squared_angdiff_and_mse: 0.3526 - val_mae: 0.1770
# Epoch 26/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0703 - squared_angdiff_and_mse: 0.0703 - mae: 0.0718
# Epoch 00026: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2561s 512ms/step - loss: 0.0703 - squared_angdiff_and_mse: 0.0703 - mae: 0.0718 - val_loss: 0.3149 - val_squared_angdiff_and_mse: 0.3149 - val_mae: 0.1780
# Epoch 27/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0664 - squared_angdiff_and_mse: 0.0664 - mae: 0.0705
# Epoch 00027: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2558s 512ms/step - loss: 0.0664 - squared_angdiff_and_mse: 0.0664 - mae: 0.0705 - val_loss: 0.3100 - val_squared_angdiff_and_mse: 0.3100 - val_mae: 0.1810
# Epoch 28/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0782 - squared_angdiff_and_mse: 0.0782 - mae: 0.0727
# Epoch 00028: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2570s 514ms/step - loss: 0.0782 - squared_angdiff_and_mse: 0.0782 - mae: 0.0726 - val_loss: 0.2986 - val_squared_angdiff_and_mse: 0.2986 - val_mae: 0.1651
# Epoch 29/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0640 - squared_angdiff_and_mse: 0.0640 - mae: 0.0701
# Epoch 00029: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2562s 512ms/step - loss: 0.0640 - squared_angdiff_and_mse: 0.0640 - mae: 0.0701 - val_loss: 0.2543 - val_squared_angdiff_and_mse: 0.2543 - val_mae: 0.1656
# Epoch 30/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0651 - squared_angdiff_and_mse: 0.0651 - mae: 0.0691
# Epoch 00030: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2557s 511ms/step - loss: 0.0651 - squared_angdiff_and_mse: 0.0651 - mae: 0.0691 - val_loss: 0.3591 - val_squared_angdiff_and_mse: 0.3591 - val_mae: 0.1741
# Epoch 31/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0560 - squared_angdiff_and_mse: 0.0560 - mae: 0.0640
# Epoch 00031: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2570s 514ms/step - loss: 0.0560 - squared_angdiff_and_mse: 0.0560 - mae: 0.0640 - val_loss: 0.3798 - val_squared_angdiff_and_mse: 0.3798 - val_mae: 0.1847
# Epoch 32/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0629 - squared_angdiff_and_mse: 0.0629 - mae: 0.0646
# Epoch 00032: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2637s 527ms/step - loss: 0.0634 - squared_angdiff_and_mse: 0.0634 - mae: 0.0647 - val_loss: 0.2694 - val_squared_angdiff_and_mse: 0.2694 - val_mae: 0.1603
# Epoch 33/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0536 - squared_angdiff_and_mse: 0.0536 - mae: 0.0624
# Epoch 00033: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2564s 513ms/step - loss: 0.0536 - squared_angdiff_and_mse: 0.0536 - mae: 0.0624 - val_loss: 0.3197 - val_squared_angdiff_and_mse: 0.3197 - val_mae: 0.1808
# Epoch 34/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0491 - squared_angdiff_and_mse: 0.0491 - mae: 0.0615
# Epoch 00034: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2565s 513ms/step - loss: 0.0491 - squared_angdiff_and_mse: 0.0491 - mae: 0.0615 - val_loss: 0.3986 - val_squared_angdiff_and_mse: 0.3986 - val_mae: 0.1915
# Epoch 35/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0495 - squared_angdiff_and_mse: 0.0495 - mae: 0.0613
# Epoch 00035: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2566s 513ms/step - loss: 0.0495 - squared_angdiff_and_mse: 0.0495 - mae: 0.0614 - val_loss: 0.3351 - val_squared_angdiff_and_mse: 0.3351 - val_mae: 0.1754
# Epoch 36/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0554 - squared_angdiff_and_mse: 0.0554 - mae: 0.0619
# Epoch 00036: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2568s 514ms/step - loss: 0.0554 - squared_angdiff_and_mse: 0.0554 - mae: 0.0619 - val_loss: 0.3060 - val_squared_angdiff_and_mse: 0.3060 - val_mae: 0.1795
# Epoch 37/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0491 - squared_angdiff_and_mse: 0.0491 - mae: 0.0599
# Epoch 00037: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2567s 513ms/step - loss: 0.0491 - squared_angdiff_and_mse: 0.0491 - mae: 0.0599 - val_loss: 0.3403 - val_squared_angdiff_and_mse: 0.3403 - val_mae: 0.1921
# Epoch 38/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0447 - squared_angdiff_and_mse: 0.0447 - mae: 0.0594
# Epoch 00038: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2563s 513ms/step - loss: 0.0447 - squared_angdiff_and_mse: 0.0447 - mae: 0.0594 - val_loss: 0.5795 - val_squared_angdiff_and_mse: 0.5795 - val_mae: 0.2232
# Epoch 39/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0473 - squared_angdiff_and_mse: 0.0473 - mae: 0.0595
# Epoch 00039: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2637s 527ms/step - loss: 0.0473 - squared_angdiff_and_mse: 0.0473 - mae: 0.0595 - val_loss: 0.4291 - val_squared_angdiff_and_mse: 0.4291 - val_mae: 0.1918
# Epoch 40/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0455 - squared_angdiff_and_mse: 0.0455 - mae: 0.0592
# Epoch 00040: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2582s 516ms/step - loss: 0.0455 - squared_angdiff_and_mse: 0.0455 - mae: 0.0592 - val_loss: 0.5319 - val_squared_angdiff_and_mse: 0.5319 - val_mae: 0.2132
# Epoch 41/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0436 - squared_angdiff_and_mse: 0.0436 - mae: 0.0580
# Epoch 00041: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2565s 513ms/step - loss: 0.0436 - squared_angdiff_and_mse: 0.0436 - mae: 0.0580 - val_loss: 0.3609 - val_squared_angdiff_and_mse: 0.3609 - val_mae: 0.1998
# Epoch 42/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0461 - squared_angdiff_and_mse: 0.0461 - mae: 0.0586
# Epoch 00042: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2559s 512ms/step - loss: 0.0461 - squared_angdiff_and_mse: 0.0461 - mae: 0.0586 - val_loss: 0.4312 - val_squared_angdiff_and_mse: 0.4312 - val_mae: 0.1950
# Epoch 43/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0433 - squared_angdiff_and_mse: 0.0433 - mae: 0.0577
# Epoch 00043: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2565s 513ms/step - loss: 0.0433 - squared_angdiff_and_mse: 0.0433 - mae: 0.0577 - val_loss: 0.4076 - val_squared_angdiff_and_mse: 0.4076 - val_mae: 0.1923
# Epoch 44/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0515 - squared_angdiff_and_mse: 0.0515 - mae: 0.0586
# Epoch 00044: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2579s 516ms/step - loss: 0.0515 - squared_angdiff_and_mse: 0.0515 - mae: 0.0586 - val_loss: 0.2614 - val_squared_angdiff_and_mse: 0.2614 - val_mae: 0.1640
# Epoch 45/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0501 - squared_angdiff_and_mse: 0.0501 - mae: 0.0586
# Epoch 00045: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2542s 508ms/step - loss: 0.0501 - squared_angdiff_and_mse: 0.0501 - mae: 0.0586 - val_loss: 0.4607 - val_squared_angdiff_and_mse: 0.4607 - val_mae: 0.1989
# Epoch 46/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0420 - squared_angdiff_and_mse: 0.0420 - mae: 0.0565
# Epoch 00046: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2523s 505ms/step - loss: 0.0420 - squared_angdiff_and_mse: 0.0420 - mae: 0.0565 - val_loss: 0.2811 - val_squared_angdiff_and_mse: 0.2811 - val_mae: 0.1742
# Epoch 47/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0435 - squared_angdiff_and_mse: 0.0435 - mae: 0.0572
# Epoch 00047: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2519s 504ms/step - loss: 0.0435 - squared_angdiff_and_mse: 0.0435 - mae: 0.0572 - val_loss: 0.4068 - val_squared_angdiff_and_mse: 0.4068 - val_mae: 0.1987
# Epoch 48/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0536 - squared_angdiff_and_mse: 0.0536 - mae: 0.0584
# Epoch 00048: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2533s 507ms/step - loss: 0.0536 - squared_angdiff_and_mse: 0.0536 - mae: 0.0584 - val_loss: 0.3582 - val_squared_angdiff_and_mse: 0.3582 - val_mae: 0.1836
# Epoch 49/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0433 - squared_angdiff_and_mse: 0.0433 - mae: 0.0571
# Epoch 00049: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2533s 507ms/step - loss: 0.0433 - squared_angdiff_and_mse: 0.0433 - mae: 0.0571 - val_loss: 0.2735 - val_squared_angdiff_and_mse: 0.2735 - val_mae: 0.1574
# Epoch 50/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0407 - squared_angdiff_and_mse: 0.0407 - mae: 0.0562
# Epoch 00050: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2529s 506ms/step - loss: 0.0407 - squared_angdiff_and_mse: 0.0407 - mae: 0.0562 - val_loss: 0.3494 - val_squared_angdiff_and_mse: 0.3494 - val_mae: 0.1858
# Epoch 51/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0435 - squared_angdiff_and_mse: 0.0435 - mae: 0.0561
# Epoch 00051: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2533s 507ms/step - loss: 0.0435 - squared_angdiff_and_mse: 0.0435 - mae: 0.0561 - val_loss: 0.4946 - val_squared_angdiff_and_mse: 0.4946 - val_mae: 0.2029
# Epoch 52/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0468 - squared_angdiff_and_mse: 0.0468 - mae: 0.0568
# Epoch 00052: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2620s 524ms/step - loss: 0.0468 - squared_angdiff_and_mse: 0.0468 - mae: 0.0568 - val_loss: 0.4385 - val_squared_angdiff_and_mse: 0.4385 - val_mae: 0.1882
# Epoch 53/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0546 - squared_angdiff_and_mse: 0.0546 - mae: 0.0580
# Epoch 00053: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2530s 506ms/step - loss: 0.0546 - squared_angdiff_and_mse: 0.0546 - mae: 0.0580 - val_loss: 0.7335 - val_squared_angdiff_and_mse: 0.7335 - val_mae: 0.2516
# Epoch 54/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0489 - squared_angdiff_and_mse: 0.0489 - mae: 0.0563
# Epoch 00054: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2527s 505ms/step - loss: 0.0489 - squared_angdiff_and_mse: 0.0489 - mae: 0.0563 - val_loss: 0.3068 - val_squared_angdiff_and_mse: 0.3068 - val_mae: 0.1632
# Epoch 55/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0491 - squared_angdiff_and_mse: 0.0491 - mae: 0.0569
# Epoch 00055: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2534s 507ms/step - loss: 0.0491 - squared_angdiff_and_mse: 0.0491 - mae: 0.0569 - val_loss: 0.4812 - val_squared_angdiff_and_mse: 0.4812 - val_mae: 0.2120
# Epoch 56/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0528 - squared_angdiff_and_mse: 0.0528 - mae: 0.0569
# Epoch 00056: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2542s 508ms/step - loss: 0.0528 - squared_angdiff_and_mse: 0.0528 - mae: 0.0569 - val_loss: 0.3205 - val_squared_angdiff_and_mse: 0.3205 - val_mae: 0.1752
# Epoch 57/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0490 - squared_angdiff_and_mse: 0.0490 - mae: 0.0560
# Epoch 00057: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2537s 507ms/step - loss: 0.0490 - squared_angdiff_and_mse: 0.0490 - mae: 0.0560 - val_loss: 0.3788 - val_squared_angdiff_and_mse: 0.3788 - val_mae: 0.1844
# Epoch 58/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0414 - squared_angdiff_and_mse: 0.0414 - mae: 0.0544
# Epoch 00058: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2595s 519ms/step - loss: 0.0414 - squared_angdiff_and_mse: 0.0414 - mae: 0.0544 - val_loss: 0.4814 - val_squared_angdiff_and_mse: 0.4814 - val_mae: 0.2021
# Epoch 59/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0347 - squared_angdiff_and_mse: 0.0347 - mae: 0.0536
# Epoch 00059: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2518s 504ms/step - loss: 0.0347 - squared_angdiff_and_mse: 0.0347 - mae: 0.0536 - val_loss: 0.4233 - val_squared_angdiff_and_mse: 0.4233 - val_mae: 0.1959
# Epoch 60/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0470 - squared_angdiff_and_mse: 0.0470 - mae: 0.0554
# Epoch 00060: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2534s 507ms/step - loss: 0.0470 - squared_angdiff_and_mse: 0.0470 - mae: 0.0553 - val_loss: 0.3359 - val_squared_angdiff_and_mse: 0.3359 - val_mae: 0.1776
# Epoch 61/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0434 - squared_angdiff_and_mse: 0.0434 - mae: 0.0541
# Epoch 00061: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2523s 505ms/step - loss: 0.0434 - squared_angdiff_and_mse: 0.0434 - mae: 0.0541 - val_loss: 0.3282 - val_squared_angdiff_and_mse: 0.3282 - val_mae: 0.1906
# Epoch 62/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0560 - squared_angdiff_and_mse: 0.0560 - mae: 0.0573
# Epoch 00062: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2523s 505ms/step - loss: 0.0560 - squared_angdiff_and_mse: 0.0560 - mae: 0.0573 - val_loss: 0.2659 - val_squared_angdiff_and_mse: 0.2659 - val_mae: 0.1743
# Epoch 63/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0429 - squared_angdiff_and_mse: 0.0429 - mae: 0.0539
# Epoch 00063: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2520s 504ms/step - loss: 0.0429 - squared_angdiff_and_mse: 0.0429 - mae: 0.0539 - val_loss: 0.2962 - val_squared_angdiff_and_mse: 0.2962 - val_mae: 0.1764
# Epoch 64/64
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0422 - squared_angdiff_and_mse: 0.0422 - mae: 0.0538
# Epoch 00064: saving model to checkpoints\20200109_1045_model_weights.h5
# 5000/5000 [==============================] - 2530s 506ms/step - loss: 0.0421 - squared_angdiff_and_mse: 0.0421 - mae: 0.0538 - val_loss: 0.4212 - val_squared_angdiff_and_mse: 0.4212 - val_mae: 0.1978

# %% [markdown]
# Evaluation

# %%
model.evaluate_generator(generator=test_generator, steps= 625)
# Out:
# [0.9662594175299629, 0.9662598, 0.3364731]

# %% [markdown]
# Testing Results

# %%
test_generator.reset()
pred=model.predict_generator(test_generator, verbose=1)
filenames=test_generator.filenames
labels = []
for filename in filenames:
    labels.append('.'.join([filename.split('_')[1].split('.')[0], filename.split('_')[1].split('.')[1]]))
labels_f = [float(x) for x in labels]
pred_f = [float(x) for x in pred]
diff = []
for i in range(len(labels)):
    diff.append(pred_f[i]-labels_f[i]) 
results=pd.DataFrame({"Filename":filenames,
                      "Label": labels,
                      "Predictions":pred.tolist(),
                      "Difference": diff})
results.to_csv("results_train_{}.csv".format(SESSION_NAME),index=False)
results.head()
# Out:
# 625/625 [==============================] - 89s 143ms/step
#                       Filename Label           Predictions  Difference
# 0   1573560928.626884_0.05.png  0.05                 [0.0]   -0.050000
# 1  1573560928.8591487_0.15.png  0.15  [0.5055615901947021]    0.355562
# 2  1573560929.0794158_0.22.png  0.22  [0.5434988737106323]    0.323499
# 3   1573560929.3035173_0.3.png   0.3   [0.609850287437439]    0.309850
# 4  1573560929.5403802_0.37.png  0.37  [0.6760601997375488]    0.306060

# %%
model.save("9_1\model_{}.h5".format(SESSION_NAME))
model.save("9_1\model_{}".format(SESSION_NAME))
# Out:
# WARNING:tensorflow:From C:\Users\eduhunlau001\.conda\envs\tensorflow\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: 9_1\model_20200109_1045\assets

# %%
model.save_weights("9_1\model_weights_{}".format(SESSION_NAME))
