# %%
import sys
assert sys.version_info >= (3, 5)

# %tensorflow_version 2.x
import tensorflow as tf 
from tensorflow import keras
assert tf.__version__ >= "2.0"

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

from time import time
import datetime

# %matplotlib inline
# %load_ext tensorboard

SEED = 42
SESSION_NAME = datetime.datetime.now().strftime("%Y%m%d_%H%M")
PI = tf.constant(np.pi)

print(SESSION_NAME)
# Out:
# 20200107_2104

# %% [markdown]
# Image Data

# %%
df_train=pd.read_csv("./labels_train.csv",dtype={'id': str, 'label': np.float32}, nrows = 40000)
df_val=pd.read_csv("./labels_val.csv",dtype={'id': str, 'label': np.float32})
df_test=pd.read_csv("./labels_test.csv",dtype={'id': str, 'label': np.float32})
IMG_PATH_TRAIN = "images_train/"
IMG_PATH_VAL = "images_val/"
IMG_PATH_TEST = "images_test/"

df_train.head()
# Out:
#                             id  label
# 0    1571743900.829366_0.1.png   0.10
# 1  1571743901.0525975_0.19.png   0.19
# 2  1571743901.2681353_0.28.png   0.28
# 3  1571743901.5050101_0.38.png   0.38
# 4  1571743901.7268791_0.46.png   0.46

# %% [markdown]
# Data Augmentation Pipeline

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

HEIGHT = 480
WIDTH = 640
TARGET_HEIGHT = 480
TARGET_WIDTH = 640
CHANNELS = 1
BATCH_SIZE = 16
NUM_TRAIN_IMAGES = 40000
NUM_VAL_IMAGES = 10000
NUM_TEST_IMAGES = 10000

datagen = ImageDataGenerator(rescale = 1/256,
                             width_shift_range = 25,
                             height_shift_range = 25,
                             rotation_range = 5,
                             brightness_range = [0.7, 1.3],
                             zoom_range = 0.25)

train_generator = datagen.flow_from_dataframe(dataframe=df_train,
                                              directory=IMG_PATH_TRAIN,
                                              x_col="id",
                                              y_col="label",
                                              seed=SEED,
                                              batch_size=BATCH_SIZE,
                                              shuffle=True,
                                              class_mode="raw",
                                              target_size=(TARGET_HEIGHT,TARGET_WIDTH),
                                              color_mode = "grayscale")

val_generator = datagen.flow_from_dataframe(dataframe=df_val,
                                            directory=IMG_PATH_VAL,
                                            x_col="id",
                                            y_col="label",
                                            seed=SEED,
                                            batch_size=BATCH_SIZE,
                                            shuffle=False,
                                            class_mode="raw",
                                            target_size=(TARGET_HEIGHT,TARGET_WIDTH),
                                            color_mode = "grayscale")

test_datagen = ImageDataGenerator(rescale = 1/256)

test_generator = test_datagen.flow_from_dataframe(dataframe=df_test,
                                                  directory=IMG_PATH_TEST,
                                                  x_col="id",
                                                  y_col="label",
                                                  batch_size=BATCH_SIZE,
                                                  class_mode="raw",
                                                  shuffle=False,
                                                  target_size=(TARGET_HEIGHT,TARGET_WIDTH),
                                                  color_mode = "grayscale")

fig = plt.figure(figsize=(12,10))
for X_batch, y_batch in train_generator:
    for i in range(1, 9):
        image = ((X_batch[i-1]*256).astype('uint8'))[:,:,0]
        a = fig.add_subplot(4, 2, i)
        imgplot = plt.imshow(image, cmap='gray', vmin = 0, vmax = 256)
        a.set_title("{}".format(i))
        plt.tight_layout()
    break
# Out:
# Found 40000 validated image filenames.
# Found 10000 validated image filenames.
# Found 10000 validated image filenames.

# %% [markdown]
# Model Definition

# %%
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization, Conv2D, MaxPooling2D
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2

model = keras.models.Sequential([
    keras.layers.Conv2D(32, 7, activation="elu", padding="same", kernel_initializer="he_normal",
                        input_shape=[TARGET_HEIGHT,TARGET_WIDTH,CHANNELS]),
    keras.layers.Conv2D(32, 3, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.BatchNormalization(),
    keras.layers.AveragePooling2D(pool_size=2),
    keras.layers.Conv2D(16, 1, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.Conv2D(32, 3, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.BatchNormalization(),
    keras.layers.AveragePooling2D(pool_size=2),
    keras.layers.Conv2D(16, 1, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.Conv2D(32, 3, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.BatchNormalization(),
    keras.layers.AveragePooling2D(pool_size=2),
    keras.layers.Conv2D(32, 1, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.Conv2D(64, 3, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.BatchNormalization(),
    keras.layers.AveragePooling2D(pool_size=2),
    keras.layers.Conv2D(32, 1, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.Conv2D(64, 3, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.BatchNormalization(),
    keras.layers.AveragePooling2D(pool_size=2),
    keras.layers.Conv2D(64, 1, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.Conv2D(128, 3, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.BatchNormalization(),
    keras.layers.AveragePooling2D(pool_size=2),
    keras.layers.Conv2D(64, 1, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.Conv2D(128, 3, activation="elu", padding="same", kernel_initializer="he_normal"),
    keras.layers.BatchNormalization(),
    keras.layers.GlobalAvgPool2D(),
    keras.layers.Flatten(),
    keras.layers.Dense(32, activation="elu"),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(16, activation="elu"),
    keras.layers.Dense(1, activation="relu")
])

model.summary()

#tf.keras.utils.plot_model(
#    model,
#    to_file='model.png',
#    show_shapes=True,
#    show_layer_names=True,
#    rankdir='TB',
#    expand_nested=False,
#    dpi=96
#)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 480, 640, 32)      1600
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 480, 640, 32)      9248
# _________________________________________________________________
# batch_normalization (BatchNo (None, 480, 640, 32)      128
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 240, 320, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 240, 320, 16)      528
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 240, 320, 32)      4640
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 240, 320, 32)      128
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 120, 160, 32)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 120, 160, 16)      528
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 120, 160, 32)      4640
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 120, 160, 32)      128
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 60, 80, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 60, 80, 32)        1056
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 60, 80, 64)        18496
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 60, 80, 64)        256
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 30, 40, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 30, 40, 32)        2080
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 30, 40, 64)        18496
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 30, 40, 64)        256
# _________________________________________________________________
# average_pooling2d_4 (Average (None, 15, 20, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 15, 20, 64)        4160
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 15, 20, 128)       73856
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 15, 20, 128)       512
# _________________________________________________________________
# average_pooling2d_5 (Average (None, 7, 10, 128)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 7, 10, 64)         8256
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 7, 10, 128)        73856
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 7, 10, 128)        512
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                4128
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 228,033
# Trainable params: 227,073
# Non-trainable params: 960
# _________________________________________________________________

# %% [markdown]
# Loss and Compilation

# %%
def squared_angdiff_and_mse(y_true, y_pred):
    squared_angdiff = tf.square( tf.atan2(tf.sin(y_pred - y_true), tf.cos(y_pred - y_true)) )
    mse = tf.square(y_pred - y_true)
    loss = tf.add(squared_angdiff, mse)
    return loss

def scheduler(epoch):
  if epoch < 3:
    return 0.004
  elif epoch < 6:
    return 0.002
  elif epoch < 20:
    return 0.001
  elif epoch < 30:
    return 0.0008
  else:
    return 0.0005

schedule = keras.callbacks.LearningRateScheduler(scheduler)

FILEPATH_SAVE='checkpoints\{}_model_weights.h5'.format(SESSION_NAME)
checkpoint = keras.callbacks.ModelCheckpoint(FILEPATH_SAVE,
                                             monitor=[squared_angdiff_and_mse],
                                             verbose=1,
                                             mode='min')

FILEPATH_TENSORBOARD_LOG = 'logs\{}'.format(SESSION_NAME)
tensorboard = keras.callbacks.TensorBoard(log_dir = FILEPATH_TENSORBOARD_LOG,
                                          histogram_freq=1,
                                          write_graph=True,
                                          write_images=True,
                                          update_freq=10000,
                                         )

model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.01,
                                                         beta_1=0.9,
                                                         beta_2=0.95,
                                                         epsilon=1e-07,
                                                         ),
              loss=squared_angdiff_and_mse,
              metrics=[squared_angdiff_and_mse, 'mae'])

# %% [markdown]
# Training

# %%
# Training constants
NUM_EPOCHS = 16

history = model.fit_generator(generator=train_generator, 
                              validation_data=val_generator,
                              validation_steps=625,
                              steps_per_epoch=5000,
                              epochs=NUM_EPOCHS,
                              callbacks=[tensorboard, checkpoint, schedule])
# Out:
# Epoch 1/16
# 4999/5000 [============================>.] - ETA: 0s - loss: 2.2496 - squared_angdiff_and_mse: 2.2496 - mae: 0.6808
# Epoch 00001: saving model to checkpoints\20200107_2104_model_weights.h5
# 5000/5000 [==============================] - 3391s 678ms/step - loss: 2.2492 - squared_angdiff_and_mse: 2.2492 - mae: 0.6807 - val_loss: 0.5824 - val_squared_angdiff_and_mse: 0.5824 - val_mae: 0.3230
# Epoch 2/16
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.4489 - squared_angdiff_and_mse: 0.4489 - mae: 0.2546
# Epoch 00002: saving model to checkpoints\20200107_2104_model_weights.h5
# 5000/5000 [==============================] - 2624s 525ms/step - loss: 0.4493 - squared_angdiff_and_mse: 0.4493 - mae: 0.2546 - val_loss: 1.4367 - val_squared_angdiff_and_mse: 1.4367 - val_mae: 0.5186
# Epoch 3/16
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.3340 - squared_angdiff_and_mse: 0.3340 - mae: 0.2141
# Epoch 00003: saving model to checkpoints\20200107_2104_model_weights.h5
# 5000/5000 [==============================] - 2622s 524ms/step - loss: 0.3340 - squared_angdiff_and_mse: 0.3340 - mae: 0.2141 - val_loss: 0.8378 - val_squared_angdiff_and_mse: 0.8378 - val_mae: 0.3914
# Epoch 4/16
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.2141 - squared_angdiff_and_mse: 0.2141 - mae: 0.1627
# Epoch 00004: saving model to checkpoints\20200107_2104_model_weights.h5
# 5000/5000 [==============================] - 2627s 525ms/step - loss: 0.2140 - squared_angdiff_and_mse: 0.2140 - mae: 0.1627 - val_loss: 0.2595 - val_squared_angdiff_and_mse: 0.2595 - val_mae: 0.1710
# Epoch 5/16
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1995 - squared_angdiff_and_mse: 0.1995 - mae: 0.1521
# Epoch 00005: saving model to checkpoints\20200107_2104_model_weights.h5
# 5000/5000 [==============================] - 2618s 524ms/step - loss: 0.1996 - squared_angdiff_and_mse: 0.1996 - mae: 0.1521 - val_loss: 0.3040 - val_squared_angdiff_and_mse: 0.3040 - val_mae: 0.1807
# Epoch 6/16
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1915 - squared_angdiff_and_mse: 0.1915 - mae: 0.1451
# Epoch 00006: saving model to checkpoints\20200107_2104_model_weights.h5
# 5000/5000 [==============================] - 2643s 529ms/step - loss: 0.1919 - squared_angdiff_and_mse: 0.1919 - mae: 0.1451 - val_loss: 0.2666 - val_squared_angdiff_and_mse: 0.2666 - val_mae: 0.2063
# Epoch 7/16
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1490 - squared_angdiff_and_mse: 0.1490 - mae: 0.1238
# Epoch 00007: saving model to checkpoints\20200107_2104_model_weights.h5
# 5000/5000 [==============================] - 2778s 556ms/step - loss: 0.1490 - squared_angdiff_and_mse: 0.1490 - mae: 0.1238 - val_loss: 0.1761 - val_squared_angdiff_and_mse: 0.1761 - val_mae: 0.1909
# Epoch 8/16
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1372 - squared_angdiff_and_mse: 0.1372 - mae: 0.1183
# Epoch 00008: saving model to checkpoints\20200107_2104_model_weights.h5
# 5000/5000 [==============================] - 2590s 518ms/step - loss: 0.1372 - squared_angdiff_and_mse: 0.1372 - mae: 0.1183 - val_loss: 0.3170 - val_squared_angdiff_and_mse: 0.3170 - val_mae: 0.1632
# Epoch 9/16
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1273 - squared_angdiff_and_mse: 0.1273 - mae: 0.1148
# Epoch 00009: saving model to checkpoints\20200107_2104_model_weights.h5
# 5000/5000 [==============================] - 2605s 521ms/step - loss: 0.1272 - squared_angdiff_and_mse: 0.1272 - mae: 0.1148 - val_loss: 0.2409 - val_squared_angdiff_and_mse: 0.2409 - val_mae: 0.2193
# Epoch 10/16
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1233 - squared_angdiff_and_mse: 0.1233 - mae: 0.1111
# Epoch 00010: saving model to checkpoints\20200107_2104_model_weights.h5
# 5000/5000 [==============================] - 2595s 519ms/step - loss: 0.1233 - squared_angdiff_and_mse: 0.1233 - mae: 0.1111 - val_loss: 0.2121 - val_squared_angdiff_and_mse: 0.2121 - val_mae: 0.1834
# Epoch 11/16
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1097 - squared_angdiff_and_mse: 0.1097 - mae: 0.1071
# Epoch 00011: saving model to checkpoints\20200107_2104_model_weights.h5
# 5000/5000 [==============================] - 2682s 536ms/step - loss: 0.1097 - squared_angdiff_and_mse: 0.1097 - mae: 0.1071 - val_loss: 0.2026 - val_squared_angdiff_and_mse: 0.2026 - val_mae: 0.1777
# Epoch 12/16
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1191 - squared_angdiff_and_mse: 0.1191 - mae: 0.1069
# Epoch 00012: saving model to checkpoints\20200107_2104_model_weights.h5
# 5000/5000 [==============================] - 2682s 536ms/step - loss: 0.1191 - squared_angdiff_and_mse: 0.1191 - mae: 0.1069 - val_loss: 0.2781 - val_squared_angdiff_and_mse: 0.2781 - val_mae: 0.2215
# Epoch 13/16
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1177 - squared_angdiff_and_mse: 0.1177 - mae: 0.1053
# Epoch 00013: saving model to checkpoints\20200107_2104_model_weights.h5
# 5000/5000 [==============================] - 2596s 519ms/step - loss: 0.1177 - squared_angdiff_and_mse: 0.1177 - mae: 0.1053 - val_loss: 0.1551 - val_squared_angdiff_and_mse: 0.1551 - val_mae: 0.1643
# Epoch 14/16
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1109 - squared_angdiff_and_mse: 0.1109 - mae: 0.1026
# Epoch 00014: saving model to checkpoints\20200107_2104_model_weights.h5
# 5000/5000 [==============================] - 2610s 522ms/step - loss: 0.1110 - squared_angdiff_and_mse: 0.1110 - mae: 0.1026 - val_loss: 0.2380 - val_squared_angdiff_and_mse: 0.2380 - val_mae: 0.1977
# Epoch 15/16
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1241 - squared_angdiff_and_mse: 0.1241 - mae: 0.1028
# Epoch 00015: saving model to checkpoints\20200107_2104_model_weights.h5
# 5000/5000 [==============================] - 2588s 518ms/step - loss: 0.1241 - squared_angdiff_and_mse: 0.1241 - mae: 0.1028 - val_loss: 0.2277 - val_squared_angdiff_and_mse: 0.2277 - val_mae: 0.2093
# Epoch 16/16
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.1201 - squared_angdiff_and_mse: 0.1201 - mae: 0.1021
# Epoch 00016: saving model to checkpoints\20200107_2104_model_weights.h5
# 5000/5000 [==============================] - 2603s 521ms/step - loss: 0.1201 - squared_angdiff_and_mse: 0.1201 - mae: 0.1021 - val_loss: 0.1984 - val_squared_angdiff_and_mse: 0.1984 - val_mae: 0.1814

# %% [markdown]
# Evaluation

# %%
model.evaluate_generator(generator=test_generator, steps= 625)
# Out:
# [0.17883653086237608, 0.17883652, 0.1762154]

# %% [markdown]
# Testing Results

# %%
test_generator.reset()
pred=model.predict_generator(test_generator, verbose=1)
filenames=test_generator.filenames
labels = []
for filename in filenames:
    labels.append('.'.join([filename.split('_')[1].split('.')[0], filename.split('_')[1].split('.')[1]]))
labels_f = [float(x) for x in labels]
pred_f = [float(x) for x in pred]
diff = []
for i in range(len(labels)):
    diff.append(pred_f[i]-labels_f[i]) 
results=pd.DataFrame({"Filename":filenames,
                      "Label": labels,
                      "Predictions":pred.tolist(),
                      "Difference": diff})
results.to_csv("results_train_{}.csv".format(SESSION_NAME),index=False)
results.head()
# Out:
# 625/625 [==============================] - 93s 148ms/step
#                       Filename Label           Predictions  Difference
# 0   1573560928.626884_0.05.png  0.05                 [0.0]   -0.050000
# 1  1573560928.8591487_0.15.png  0.15  [0.9756726026535034]    0.825673
# 2  1573560929.0794158_0.22.png  0.22  [0.9437374472618103]    0.723737
# 3   1573560929.3035173_0.3.png   0.3  [0.9535079002380371]    0.653508
# 4  1573560929.5403802_0.37.png  0.37  [1.0253363847732544]    0.655336

# %%
model.save("7_1\model_{}.h5".format(SESSION_NAME))
model.save("7_1\model_{}".format(SESSION_NAME))
# Out:
# WARNING:tensorflow:From C:\Users\eduhunlau001\.conda\envs\tensorflow\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: 7_1\model_20200107_2104\assets

# %%
model.save_weights("7_1\model_weights_{}".format(SESSION_NAME))
